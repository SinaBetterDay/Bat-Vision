# %%
pip install roboflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="RprU24vHTT6tVapefngb")  # Replace with your actual API key
project = rf.workspace().project("parking-space-4-mboaw")  # Replace with your project name
model = project.version("1").model  # Replace with your model version
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
image_path = "/Users/suhanishokeen/Desktop/Zoom.png"

# Perform inference
prediction = model.predict(image_path).json()

# Print prediction output
print(prediction)
# Out:
# {'predictions': [{'x': 1369.5, 'y': 526.5, 'width': 137.0, 'height': 215.0, 'confidence': 0.8835273385047913, 'class': 'vacant', 'class_id': 1, 'detection_id': 'bad69e7d-c432-4ae0-a2f4-e2fc564ba850', 'image_path': '/Users/suhanishokeen/Desktop/Zoom.png', 'prediction_type': 'ObjectDetectionModel'}, {'x': 1252.0, 'y': 524.5, 'width': 168.0, 'height': 217.0, 'confidence': 0.8780535459518433, 'class': 'vacant', 'class_id': 1, 'detection_id': '99fb9155-2c87-4932-9910-a5da8f1024bc', 'image_path': '/Users/suhanishokeen/Desktop/Zoom.png', 'prediction_type': 'ObjectDetectionModel'}, {'x': 426.0, 'y': 513.0, 'width': 150.0, 'height': 216.0, 'confidence': 0.8701841235160828, 'class': 'vacant', 'class_id': 1, 'detection_id': '3a6ed614-a47c-47eb-ab8a-acff9c88034a', 'image_path': '/Users/suhanishokeen/Desktop/Zoom.png', 'prediction_type': 'ObjectDetectionModel'}, {'x': 300.0, 'y': 514.5, 'width': 148.0, 'height': 221.0, 'confidence': 0.8541473746299744, 'class': 'vacant', 'class_id': 1, 'detection
# ...

# %%
import cv2
import matplotlib.pyplot as plt

# Get the image with bounding boxes drawn
image_with_boxes = model.predict(image_path).save("output.jpg")

# Display the image
img = cv2.imread("output.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.axis("off")
plt.show()
